# %%
from mqt.bench import get_benchmark

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="ae", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#                       ┌──────┐ ░ ┌─┐
# eval_0: ──────────────┤0     ├─░─┤M├────────────
#                       │      │ ░ └╥┘┌─┐
# eval_1: ──────────────┤1     ├─░──╫─┤M├─────────
#                       │      │ ░  ║ └╥┘┌─┐
# eval_2: ──────────────┤2 QPE ├─░──╫──╫─┤M├──────
#                       │      │ ░  ║  ║ └╥┘┌─┐
# eval_3: ──────────────┤3     ├─░──╫──╫──╫─┤M├───
#         ┌────────────┐│      │ ░  ║  ║  ║ └╥┘┌─┐
#      q: ┤ Ry(0.9273) ├┤4     ├─░──╫──╫──╫──╫─┤M├
#         └────────────┘└──────┘ ░  ║  ║  ║  ║ └╥┘
# meas: 5/══════════════════════════╩══╩══╩══╩══╩═
#                                   0  1  2  3  4

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="dj", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#      ┌───┐     ┌─────────┐┌───┐ ░ ┌─┐
# q_0: ┤ H ├─────┤0        ├┤ H ├─░─┤M├─────────
#      ├───┤     │         │├───┤ ░ └╥┘┌─┐
# q_1: ┤ H ├─────┤1        ├┤ H ├─░──╫─┤M├──────
#      ├───┤     │         │├───┤ ░  ║ └╥┘┌─┐
# q_2: ┤ H ├─────┤2 Oracle ├┤ H ├─░──╫──╫─┤M├───
#      ├───┤     │         │├───┤ ░  ║  ║ └╥┘┌─┐
# q_3: ┤ H ├─────┤3        ├┤ H ├─░──╫──╫──╫─┤M├
#      ├───┤┌───┐│         │└───┘ ░  ║  ║  ║ └╥┘
# q_4: ┤ X ├┤ H ├┤4        ├──────░──╫──╫──╫──╫─
#      └───┘└───┘└─────────┘      ░  ║  ║  ║  ║
# c: 4/══════════════════════════════╩══╩══╩══╩═
#                                    0  1  2  3

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="ghz", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#                             ┌───┐ ░ ┌─┐
#    q_0: ────────────────────┤ X ├─░─┤M├────────────
#                        ┌───┐└─┬─┘ ░ └╥┘┌─┐
#    q_1: ───────────────┤ X ├──■───░──╫─┤M├─────────
#                   ┌───┐└─┬─┘      ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├──■────────░──╫──╫─┤M├──────
#              ┌───┐└─┬─┘           ░  ║  ║ └╥┘┌─┐
#    q_3: ─────┤ X ├──■─────────────░──╫──╫──╫─┤M├───
#         ┌───┐└─┬─┘                ░  ║  ║  ║ └╥┘┌─┐
#    q_4: ┤ H ├──■──────────────────░──╫──╫──╫──╫─┤M├
#         └───┘                     ░  ║  ║  ║  ║ └╥┘
# meas: 5/═════════════════════════════╩══╩══╩══╩══╩═
#                                      0  1  2  3  4

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="graphstate", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌──────────────────────────────────────────────┐ ░ ┌─┐
#    q_0: ┤0                                             ├─░─┤M├──────
#         │                                              │ ░ └╥┘┌─┐
#    q_1: ┤1 graph: [[0. 1. 1.]
#  [1. 0. 1.]
#  [1. 1. 0.]] ├─░──╫─┤M├───
#         │                                              │ ░  ║ └╥┘┌─┐
#    q_2: ┤2                                             ├─░──╫──╫─┤M├
#         └──────────────────────────────────────────────┘ ░  ║  ║ └╥┘
# meas: 3/════════════════════════════════════════════════════╩══╩══╩═
#                                                             0  1  2

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qaoa", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌───┐┌──────────────────────────────────────┐»
#    q_0: ┤ H ├┤0                                     ├»
#         ├───┤│                                      │»
#    q_1: ┤ H ├┤1 exp(-it (IZZ + ZIZ + ZZI))(-5.6691) ├»
#         ├───┤│                                      │»
#    q_2: ┤ H ├┤2                                     ├»
#         └───┘└──────────────────────────────────────┘»
# meas: 3/═════════════════════════════════════════════»
#                                                      »
# «        ┌──────────────────────────────────────┐»
# «   q_0: ┤0                                     ├»
# «        │                                      │»
# «   q_1: ┤1 exp(-it (XII + IXI + IIX))(-1.1075) ├»
# «        │                                      │»
# «   q_2: ┤2                                     ├»
# «        └──────────────────────────────────────┘»
# «meas: 3/════════════════════════════════════════»
# «                                                »
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="portfolioqaoa", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌───┐┌────────────────────────────────────────────────────────┐»
#    q_0: ┤ H ├┤0                                                       ├»
#         ├───┤│                                                        │»
#    q_1: ┤ H ├┤1 exp(-it (IIZ + IZI + ZII + IZZ + ZIZ + ZZI))(-3.5143) ├»
#         ├───┤│                                                        │»
#    q_2: ┤ H ├┤2                                                       ├»
#         └───┘└────────────────────────────────────────────────────────┘»
# meas: 3/═══════════════════════════════════════════════════════════════»
#                                                                        »
# «        ┌─────────────────────────────────────┐»
# «   q_0: ┤0                                    ├»
# «        │                                     │»
# «   q_1: ┤1 exp(-it (XII + IXI + IIX))(7.1369) ├»
# «        │                                     │»
# «   q_2: ┤2                                    ├»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qft", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌──────┐ ░ ┌─┐
#    q_0: ┤0     ├─░─┤M├──────
#         │      │ ░ └╥┘┌─┐
#    q_1: ┤1 QFT ├─░──╫─┤M├───
#         │      │ ░  ║ └╥┘┌─┐
#    q_2: ┤2     ├─░──╫──╫─┤M├
#         └──────┘ ░  ║  ║ └╥┘
# meas: 3/════════════╩══╩══╩═
#                     0  1  2

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="vqe", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         »
#    q_0: »
#         »
#    q_1: »
#         »
#    q_2: »
#         »
# meas: 3/»
#         »
# «        ┌─────────────────────────────────────────────────────────────────────────────────────────┐»
# «   q_0: ┤0                                                                                        ├»
# «        │                                                                                         │»
# «   q_1: ┤1 RealAmplitudes(-1.2341,-1.6856,-3.041,-0.83969,0.21058,1.6149,1.6643,0.35805,-0.33767) ├»
# «        │                                                                                         │»
# «   q_2: ┤2                                                                                        ├»
# «        └─────────────────────────────────────────────────────────────────────────────────────────┘»
# «meas: 3/═══════════════════════════════════════════════════════════════════════════════════════════»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="portfoliovqe", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         »
#    q_0: »
#         »
#    q_1: »
#         »
#    q_2: »
#         »
# meas: 3/»
#         »
# «        ┌─────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «   q_0: ┤0                                                                                                    ├»
# «        │                                                                                                     │»
# «   q_1: ┤1 TwoLocal(4.5962,6.4975,-3.5916,6.3864,4.4856,-0.91803,-3.7934,-6.1654,-2.6835,2.7105,1.2997,5.772) ├»
# «        │                                                                                                     │»
# «   q_2: ┤2                                                                                                    ├»
# «        └─────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qftentangled", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#                   ┌───┐┌──────┐ ░ ┌─┐
#    q_0: ──────────┤ X ├┤0     ├─░─┤M├──────
#              ┌───┐└─┬─┘│      │ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──■──┤1 QFT ├─░──╫─┤M├───
#         ┌───┐└─┬─┘     │      │ ░  ║ └╥┘┌─┐
#    q_2: ┤ H ├──■───────┤2     ├─░──╫──╫─┤M├
#         └───┘          └──────┘ ░  ║  ║ └╥┘
# meas: 3/═══════════════════════════╩══╩══╩═
#                                    0  1  2

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qpeexact", level="alg", circuit_size=7)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#      ┌───┐                                    ┌──────────┐ ░ ┌─┐
# q_0: ┤ H ├─■──────────────────────────────────┤0         ├─░─┤M├───────────────
#      ├───┤ │                                  │          │ ░ └╥┘┌─┐
# q_1: ┤ H ├─┼──────────■───────────────────────┤1         ├─░──╫─┤M├────────────
#      ├───┤ │          │                       │          │ ░  ║ └╥┘┌─┐
# q_2: ┤ H ├─┼──────────┼────────■──────────────┤2         ├─░──╫──╫─┤M├─────────
#      ├───┤ │          │        │              │  IQFT_dg │ ░  ║  ║ └╥┘┌─┐
# q_3: ┤ H ├─┼──────────┼────────┼────────■─────┤3         ├─░──╫──╫──╫─┤M├──────
#      ├───┤ │          │        │        │     │          │ ░  ║  ║  ║ └╥┘┌─┐
# q_4: ┤ H ├─┼──────────┼────────┼────────┼─────┤4         ├─░──╫──╫──╫──╫─┤M├───
#      ├───┤ │          │        │        │     │          │ ░  ║  ║  ║  ║ └╥┘┌─┐
# q_5: ┤ H ├─┼──────────┼────────┼────────┼─────┤5         ├─░──╫──╫──╫──╫──╫─┤M├
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qpeinexact", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#      ┌───┐                                     ┌──────────┐ ░ ┌─┐
# q_0: ┤ H ├─■───────────────────────────────────┤0         ├─░─┤M├─────────
#      ├───┤ │                                   │          │ ░ └╥┘┌─┐
# q_1: ┤ H ├─┼─────────■─────────────────────────┤1         ├─░──╫─┤M├──────
#      ├───┤ │         │                         │  IQFT_dg │ ░  ║ └╥┘┌─┐
# q_2: ┤ H ├─┼─────────┼────────■────────────────┤2         ├─░──╫──╫─┤M├───
#      ├───┤ │         │        │                │          │ ░  ║  ║ └╥┘┌─┐
# q_3: ┤ H ├─┼─────────┼────────┼────────■───────┤3         ├─░──╫──╫──╫─┤M├
#      ├───┤ │P(π/16)  │P(π/8)  │P(π/4)  │P(π/2) └──────────┘ ░  ║  ║  ║ └╥┘
# psi: ┤ X ├─■─────────■────────■────────■────────────────────░──╫──╫──╫──╫─
#      └───┘                                                  ░  ║  ║  ║  ║
# c: 4/══════════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                0  1  2  3

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="random", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌───────────────┐┌───┐┌─────┐┌───┐┌───┐┌───┐┌────────────┐     ┌──────┐»
#    q_0: ┤ U2(π/4,-3π/4) ├┤ X ├┤ Tdg ├┤ X ├┤ T ├┤ X ├┤ U2(0,3π/4) ├──■──┤ √Xdg ├»
#         └───────────────┘└─┬─┘└─────┘└─┬─┘├───┤└─┬─┘└────────────┘┌─┴─┐└┬───┬─┘»
#    q_1: ───■───────────────┼───────────■──┤ H ├──┼────────────────┤ X ├─┤ H ├──»
#            │U1(5.2889)     │              └───┘  │                └─┬─┘ └───┘  »
#    q_2: ───■───────────────■─────────────────────■──────────────────■──────────»
#                                                                                »
# meas: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                         ░ ┌─┐
# «   q_0: ─■────────────X──░─┤M├──────
# «         │U1(2.0262)  │  ░ └╥┘┌─┐
# «   q_1: ─■────────────■──░──╫─┤M├───
# «                      │  ░  ║ └╥┘┌─┐
# «   q_2: ──────────────X──░──╫──╫─┤M├
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="realamprandom", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         »
#    q_0: »
#         »
#    q_1: »
#         »
#    q_2: »
#         »
# meas: 3/»
#         »
# «        ┌───────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «   q_0: ┤0                                                                                                      ├»
# «        │                                                                                                       │»
# «   q_1: ┤1 RealAmplitudes(6.0067,1.3049,5.2053,0.93797,3.222,0.85401,4.3293,5.2889,2.6736,6.0125,5.1857,2.1251) ├»
# «        │                                                                                                       │»
# «   q_2: ┤2                                                                                                      ├»
# «        └───────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="twolocalrandom", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         »
#    q_0: »
#         »
#    q_1: »
#         »
#    q_2: »
#         »
# meas: 3/»
#         »
# «        ┌─────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «   q_0: ┤0                                                                                                ├»
# «        │                                                                                                 │»
# «   q_1: ┤1 TwoLocal(6.0067,1.3049,5.2053,0.93797,3.222,0.85401,4.3293,5.2889,2.6736,6.0125,5.1857,2.1251) ├»
# «        │                                                                                                 │»
# «   q_2: ┤2                                                                                                ├»
# «        └─────────────────────────────────────────────────────────────────────────────────────────────────┘»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qwalk-noancilla", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#              ┌───┐                    ┌───┐                         ┌───┐     »
# node_0: ─────┤ X ├────────────────────┤ X ├─────────────────────────┤ X ├─────»
#              └─┬─┘┌───┐┌───┐          └─┬─┘┌───┐┌───┐               └─┬─┘┌───┐»
# node_1: ───────■──┤ X ├┤ X ├────────────■──┤ X ├┤ X ├─────────────────■──┤ X ├»
#                │  └─┬─┘├───┤┌───┐       │  └─┬─┘├───┤┌───┐            │  └─┬─┘»
# node_2: ───────■────■──┤ X ├┤ X ├───────■────■──┤ X ├┤ X ├────────────■────■──»
#                │    │  └─┬─┘├───┤┌───┐  │    │  └─┬─┘├───┤┌───┐       │    │  »
# node_3: ───────■────■────■──┤ X ├┤ X ├──■────■────■──┤ X ├┤ X ├───────■────■──»
#         ┌───┐  │    │    │  └─┬─┘├───┤  │    │    │  └─┬─┘├───┤┌───┐  │    │  »
#   coin: ┤ H ├──■────■────■────■──┤ X ├──■────■────■────■──┤ X ├┤ H ├──■────■──»
#         └───┘                    └───┘                    └───┘└───┘          »
# meas: 5/══════════════════════════════════════════════════════════════════════»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="wstate", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#           ┌──────────┐                                                      »
#    q_0: ──┤ Ry(-π/4) ├────────────────────────────────────────────────────■─»
#         ┌─┴──────────┴─┐                                  ┌─────────────┐ │ »
#    q_1: ┤ Ry(-0.95532) ├────────────────────────────────■─┤ Ry(0.95532) ├─■─»
#         └─┬──────────┬─┘                    ┌─────────┐ │ └─────────────┘   »
#    q_2: ──┤ Ry(-π/3) ├────────────────────■─┤ Ry(π/3) ├─■────────■──────────»
#         ┌─┴──────────┴┐    ┌────────────┐ │ └─────────┘        ┌─┴─┐        »
#    q_3: ┤ Ry(-1.1071) ├──■─┤ Ry(1.1071) ├─■──────■─────────────┤ X ├────────»
#         └────┬───┬────┘  │ └────────────┘      ┌─┴─┐           └───┘        »
#    q_4: ─────┤ X ├───────■─────────────────────┤ X ├────────────────────────»
#              └───┘                             └───┘                        »
# meas: 5/════════════════════════════════════════════════════════════════════»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="grover-v-chain", level="alg", circuit_size=10)
qc_algorithmic_level.draw()
#print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#          ┌───┐┌─────┐┌─────┐┌─────┐┌─────┐┌─────┐┌─────┐┌─────┐┌─────┐┌─────┐»
#     q_0: ┤ H ├┤0    ├┤0    ├┤0    ├┤0    ├┤0    ├┤0    ├┤0    ├┤0    ├┤0    ├»
#          ├───┤│     ││     ││     ││     ││     ││     ││     ││     ││     │»
#     q_1: ┤ H ├┤1    ├┤1    ├┤1    ├┤1    ├┤1    ├┤1    ├┤1    ├┤1    ├┤1    ├»
#          ├───┤│     ││     ││     ││     ││     ││     ││     ││     ││     │»
#     q_2: ┤ H ├┤2    ├┤2    ├┤2    ├┤2    ├┤2    ├┤2    ├┤2    ├┤2    ├┤2    ├»
#          ├───┤│     ││     ││     ││     ││     ││     ││     ││     ││     │»
#     q_3: ┤ H ├┤3    ├┤3    ├┤3    ├┤3    ├┤3    ├┤3    ├┤3    ├┤3    ├┤3    ├»
#          ├───┤│     ││     ││     ││     ││     ││     ││     ││     ││     │»
#     q_4: ┤ H ├┤4    ├┤4    ├┤4    ├┤4    ├┤4    ├┤4    ├┤4    ├┤4    ├┤4    ├»
#          ├───┤│     ││     ││     ││     ││     ││     ││     ││     ││     │»
#     q_5: ┤ H ├┤5    ├┤5    ├┤5    ├┤5    ├┤5    ├┤5    ├┤5    ├┤5    ├┤5    ├»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qwalk-v-chain", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#              ┌────┐                     ┌────┐                          ┌────┐»
# node_0: ─────┤0   ├─────────────────────┤0   ├──────────────────────────┤0   ├»
#              │    │┌────┐┌───┐          │    │┌────┐┌───┐               │    │»
# node_1: ─────■    ├┤0   ├┤ X ├──────────■    ├┤0   ├┤ X ├───────────────■    ├»
#              │    ││    │├───┤┌───┐     │    ││    │├───┤┌───┐          │    │»
# node_2: ─────■    ├■    ├┤ X ├┤ X ├─────■    ├■    ├┤ X ├┤ X ├──────────■    ├»
#              │    ││    │└─┬─┘├───┤┌───┐│    ││    │└─┬─┘├───┤┌───┐     │    │»
# node_3: ─────■  X ├■  X ├──■──┤ X ├┤ X ├■  X ├■  X ├──■──┤ X ├┤ X ├─────■  X ├»
#         ┌───┐│    ││    │  │  └─┬─┘├───┤│    ││    │  │  └─┬─┘├───┤┌───┐│    │»
#   coin: ┤ H ├■    ├■    ├──■────■──┤ X ├■    ├■    ├──■────■──┤ X ├┤ H ├■    ├»
#         └───┘│    ││    │          └───┘│    ││    │          └───┘└───┘│    │»
#  anc_0: ─────┤1   ├┤1   ├───────────────┤1   ├┤1   ├────────────────────┤1   ├»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="grover-noancilla", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌───┐┌────┐ ░ ┌─┐
#    q_0: ┤ H ├┤0   ├─░─┤M├──────
#         ├───┤│    │ ░ └╥┘┌─┐
#    q_1: ┤ H ├┤1 Q ├─░──╫─┤M├───
#         ├───┤│    │ ░  ║ └╥┘┌─┐
#   flag: ┤ X ├┤2   ├─░──╫──╫─┤M├
#         └───┘└────┘ ░  ║  ║ └╥┘
# meas: 3/═══════════════╩══╩══╩═
#                        0  1  2

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="qnn", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌──────────────────────┐»
#    q_0: ┤0                     ├»
#         │                      │»
#    q_1: ┤1 ZZFeatureMap(1,1,1) ├»
#         │                      │»
#    q_2: ┤2                     ├»
#         └──────────────────────┘»
# meas: 3/════════════════════════»
#                                 »
# «        ┌─────────────────────────────────────────────────────────────┐ ░ ┌─┐»
# «   q_0: ┤0                                                            ├─░─┤M├»
# «        │                                                             │ ░ └╥┘»
# «   q_1: ┤1 RealAmplitudes(6.0067,1.3049,5.2053,0.93797,3.222,0.85401) ├─░──╫─»
# «        │                                                             │ ░  ║ »
# «   q_2: ┤2                                                            ├─░──╫─»
# «        └─────────────────────────────────────────────────────────────┘ ░  ║ »
# «meas: 3/═══════════════════════════════════════════════════════════════════╩═»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="pricingcall", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌───────┐┌────┐ ░ ┌─┐
#    q_0: ┤0      ├┤0   ├─░─┤M├──────────────────
#         │       ││    │ ░ └╥┘┌─┐
#    q_1: ┤1 P(X) ├┤1   ├─░──╫─┤M├───────────────
#         │       ││    │ ░  ║ └╥┘┌─┐
#    q_2: ┤2      ├┤2   ├─░──╫──╫─┤M├────────────
#         └───────┘│    │ ░  ║  ║ └╥┘┌─┐
#    q_3: ─────────┤3 F ├─░──╫──╫──╫─┤M├─────────
#                  │    │ ░  ║  ║  ║ └╥┘┌─┐
#    q_4: ─────────┤4   ├─░──╫──╫──╫──╫─┤M├──────
#                  │    │ ░  ║  ║  ║  ║ └╥┘┌─┐
#    q_5: ─────────┤5   ├─░──╫──╫──╫──╫──╫─┤M├───
#                  │    │ ░  ║  ║  ║  ║  ║ └╥┘┌─┐
#    q_6: ─────────┤6   ├─░──╫──╫──╫──╫──╫──╫─┤M├
#                  └────┘ ░  ║  ║  ║  ║  ║  ║ └╥┘
# meas: 7/═══════════════════╩══╩══╩══╩══╩══╩══╩═
#                            0  1  2  3  4  5  6

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="pricingput", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         ┌───────┐┌────┐ ░ ┌─┐
#    q_0: ┤0      ├┤0   ├─░─┤M├──────────────────
#         │       ││    │ ░ └╥┘┌─┐
#    q_1: ┤1 P(X) ├┤1   ├─░──╫─┤M├───────────────
#         │       ││    │ ░  ║ └╥┘┌─┐
#    q_2: ┤2      ├┤2   ├─░──╫──╫─┤M├────────────
#         └───────┘│    │ ░  ║  ║ └╥┘┌─┐
#    q_3: ─────────┤3 F ├─░──╫──╫──╫─┤M├─────────
#                  │    │ ░  ║  ║  ║ └╥┘┌─┐
#    q_4: ─────────┤4   ├─░──╫──╫──╫──╫─┤M├──────
#                  │    │ ░  ║  ║  ║  ║ └╥┘┌─┐
#    q_5: ─────────┤5   ├─░──╫──╫──╫──╫──╫─┤M├───
#                  │    │ ░  ║  ║  ║  ║  ║ └╥┘┌─┐
#    q_6: ─────────┤6   ├─░──╫──╫──╫──╫──╫──╫─┤M├
#                  └────┘ ░  ║  ║  ║  ║  ║  ║ └╥┘
# meas: 7/═══════════════════╩══╩══╩══╩══╩══╩══╩═
#                            0  1  2  3  4  5  6

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="routing", level="alg", circuit_size=2)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         »
#    q_0: »
#         »
#    q_1: »
#         »
# meas: 2/»
#         »
# «        ┌─────────────────────────────────────────────────────────────────────────────────┐»
# «   q_0: ┤0                                                                                ├»
# «        │  RealAmplitudes(-2.1197,-1.043,-0.16339,0.14436,2.7198,-0.51993,-2.3977,-1.496) │»
# «   q_1: ┤1                                                                                ├»
# «        └─────────────────────────────────────────────────────────────────────────────────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════════════════════»
# «                                                                                           »
# «         ░ ┌─┐
# «   q_0: ─░─┤M├───
# «         ░ └╥┘┌─┐
# «   q_1: ─░──╫─┤M├
# «         ░  ║ └╥┘
# «meas: 2/════╩══╩═
# «            0  1

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="tsp", level="alg", circuit_size=2)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
#         »
#    q_0: »
#         »
#    q_1: »
#         »
#    q_2: »
#         »
#    q_3: »
#         »
# meas: 4/»
#         »
# «        ┌───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «   q_0: ┤0                                                                                                                                                                                          ├»
# «        │                                                                                                                                                                                           │»
# «   q_1: ┤1                                                                                                                                                                                          ├»
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="groundstate", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 qc_algorithmic_level = get_benchmark(benchmark_name="groundstate", level="alg", circuit_size=3)
#       2 print(qc_algorithmic_level.draw()) # drawing the circuit
#
# File ~/anaconda3/envs/mqt/lib/python3.12/site-packages/mqt/bench/benchmark_generator.py:380, in get_benchmark(benchmark_name, level, circuit_size, benchmark_instance_name, compiler, compiler_settings, provider_name, device_name, **kwargs)
#     378 if benchmark_name in ["shor", "groundstate"] and not isinstance(benchmark_instance_name, str):
#     379     msg = "benchmark_instance_name must be defined for this benchmark."
# --> 380     raise ValueError(msg)
#     382 lib = get_module_for_benchmark(
#     383     benchmark_name.split("-")[0]
#     384 )  # split is used to filter the ancillary mode for grover and qwalk
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="shor", level="alg", circuit_size=5)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 qc_algorithmic_level = get_benchmark(benchmark_name="shor", level="alg", circuit_size=5)
#       2 print(qc_algorithmic_level.draw()) # drawing the circuit
#
# File ~/anaconda3/envs/mqt/lib/python3.12/site-packages/mqt/bench/benchmark_generator.py:380, in get_benchmark(benchmark_name, level, circuit_size, benchmark_instance_name, compiler, compiler_settings, provider_name, device_name, **kwargs)
#     378 if benchmark_name in ["shor", "groundstate"] and not isinstance(benchmark_instance_name, str):
#     379     msg = "benchmark_instance_name must be defined for this benchmark."
# --> 380     raise ValueError(msg)
#     382 lib = get_module_for_benchmark(
#     383     benchmark_name.split("-")[0]
#     384 )  # split is used to filter the ancillary mode for grover and qwalk
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="su2ramdom", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 qc_algorithmic_level = get_benchmark(benchmark_name="su2ramdom", level="alg", circuit_size=3)
#       2 print(qc_algorithmic_level.draw()) # drawing the circuit
#
# File ~/anaconda3/envs/mqt/lib/python3.12/site-packages/mqt/bench/benchmark_generator.py:368, in get_benchmark(benchmark_name, level, circuit_size, benchmark_instance_name, compiler, compiler_settings, provider_name, device_name, **kwargs)
#     366 if benchmark_name not in get_supported_benchmarks():
#     367     msg = f"Selected benchmark is not supported. Valid benchmarks are {get_supported_benchmarks()}."
# --> 368     raise ValueError(msg)
#     370 if level not in get_supported_levels():
#     371     msg = f"Selected level must be in {get_supported_levels()}."
#
# ...

# %%
qc_algorithmic_level = get_benchmark(benchmark_name="'groundstate’", level="alg", circuit_size=3)
print(qc_algorithmic_level.draw()) # drawing the circuit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 qc_algorithmic_level = get_benchmark(benchmark_name="'groundstate’", level="alg", circuit_size=3)
#       2 print(qc_algorithmic_level.draw()) # drawing the circuit
#
# File ~/anaconda3/envs/mqt/lib/python3.12/site-packages/mqt/bench/benchmark_generator.py:368, in get_benchmark(benchmark_name, level, circuit_size, benchmark_instance_name, compiler, compiler_settings, provider_name, device_name, **kwargs)
#     366 if benchmark_name not in get_supported_benchmarks():
#     367     msg = f"Selected benchmark is not supported. Valid benchmarks are {get_supported_benchmarks()}."
# --> 368     raise ValueError(msg)
#     370 if level not in get_supported_levels():
#     371     msg = f"Selected level must be in {get_supported_levels()}."
#
# ...
